# %% [markdown]
# <a href="https://colab.research.google.com/github/atakhadivi/Algorithmic-Trading/blob/master/pass_list_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first_name = input('First name:')
last_name = input('Last name:')
year = input('Birth year:')
month = input('Birth month:')
day = input('Birth date:')
pet_name = input('Pet name:')
phone_number = input('Phone number:')
nick_name = input('Nick name:')
partner_name = input('Partner First Name:')
partner_lastname = input('Partner Last Name:')
id = input('Id card number(code melli):')

# %%
list_name = [first_name, last_name, year, month, day, pet_name, phone_number, nick_name, partner_name, partner_lastname, id]
special_character=['@','!','$']

# %%
f = open(first_name + "_pwd.txt", 'w')

#first step

# list
for i in list_name:
  print(i)
  w = i
  if len(w) >= 6:
    f.write(w+"\n")

#list first capital letter
for i in list_name:
  print(i.title())
  w = i.title()
  if len(w) >= 6:
    f.write(w+"\n")

#list capital
for i in list_name:
  print(i.upper())
  w = i.upper()
  if len(w) >= 6:
    f.write(w+"\n")

#special_character
for i in special_character:
    print(i)
    w = i
    if len(w) >= 6:
      f.write(w+"\n")
#end first step

#second step

#list + list
for i in list_name:
  print(i + i)
  w = i + i
  if len(w) >= 6:
    f.write(w+"\n")

#list + list capital
for i in list_name:
  print(i + i.upper())
  w = i + i.upper()
  if len(w) >= 6:
    f.write(w+"\n")

#list + list first capital
for i in list_name:
  print(i + i.title())
  w = i + i.title()
  if len(w) >= 6:
    f.write(w+"\n")

#list + special character
for i in special_character:
  for x in list_name:
    print(x + i)
    w = x + i
    if len(w) >= 6:
      f.write(w+"\n")

#list capital + list
for i in list_name:
  for x in list_name:
    print(i.upper() + x)
    w = i.upper() + x
    if len(w) >= 6:
      f.write(w+"\n")

#list capital + list capital
for i in list_name:
  for x in list_name:
    print(i.upper() + x.upper())
    w = i.upper() + x.upper()
    if len(w) >= 6:
      f.write(w+"\n")

#list capital + list first capital
for i in list_name:
  for x in list_name:
    print(i.upper() + x.title())
    w = i.upper() + x.title()
    if len(w) >= 6:
      f.write(w+"\n")

#list capital + special character
for i in list_name:
  for x in special_character:
    print(i.upper() + x)
    w = i.upper() + x
    if len(w) >= 6:
      f.write(w+"\n")

#list first capital + list
for i in list_name:
  for x in list_name:
    print(i.title() + x)
    w = i.title() + x
    if len(w) >= 6:
      f.write(w+"\n")

#list first capital + list capital
for i in list_name:
  for x in list_name:
    print(i.title() + x.upper())
    w = i.title() + x.upper()
    if len(w) >= 6:
      f.write(w+"\n")

#list first capital + list first capital
for i in list_name:
  for x in list_name:
    print(i.title() + x.title())
    w = i.title() + x.title()
    if len(w) >= 6:
      f.write(w+"\n")

#list first capital + special character
for i in list_name:
  for x in special_character:
    print(i.title() + x)
    w = i.title() + x
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list
for i in special_character:
  for x in list_name:
    print(i + x)
    w = i + x
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list capital
for i in special_character:
  for x in list_name:
    print(i + x.upper())
    w = i + x.upper()
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list first capital
for i in special_character:
  for x in list_name:
    print(i + x.title())
    w = i + x.title()
    if len(w) >= 6:
      f.write(w+"\n")

#special character + special charcter
for i in special_character:
  for x in special_character:
    print(i + x)
    w = i + x
    if len(w) >= 6:
      f.write(w+"\n")

#list + list + list
for i in list_name:
  print(i + i + i)
  w = i + i + i
  if len(w) >= 6:
    f.write(w+"\n")

#list + list + list capital
for i in list_name:
  print(i + i + i.upper())
  w = i + i + i.upper()
  if len(w) >= 6:
    f.write(w+"\n")

#list + list + list first capital
for i in list_name:
  print(i + i + i.title())
  w = i + i + i.title()
  if len(w) >= 6:
    f.write(w+"\n")

#list + list + special character
for i in list_name:
  for x in special_character:
    print(i + i + x)
    w = i + i + x
    if len(w) >= 6:
      f.write(w+"\n")

#list + list capital + list
for i in list_name:
  print(i + i.upper() + i)
  w = i + i.upper() + i
  if len(w) >= 6:
    f.write(w+"\n")

#list + list capital + list capital
for i in list_name:
  print(i + i.upper() + i.upper())
  w = i + i.upper() + i.upper()
  if len(w) >= 6:
    f.write(w+"\n")

#list + list capital + list first capital
for i in list_name:
  print(i + i.upper() + i.title())
  w = i + i.upper() + i.title()
  if len(w) >= 6:
    f.write(w+"\n")

#list + list capital + special character
for i in list_name:
  for x in special_character:
    print(i + i.upper() + x)
    w = i + i.upper() + x
    if len(w) >= 6:
      f.write(w+"\n")

#list + list first capital + list
for i in list_name:
  print(i + i.title() + i)
  w = i + i.title() + i
  if len(w) >= 6:
    f.write(w+"\n")

#list + list first capital + list capital
for i in list_name:
  print(i + i.title() + i.upper())
  w = i + i.title() + i.upper()
  if len(w) >= 6:
    f.write(w+"\n")

#list + list first capital + list first capital
for i in list_name:
  print(i + i.title() + i.title())
  w = i + i.title() + i.title()
  if len(w) >= 6:
    f.write(w+"\n")

#list + list first capital + special character
for i in list_name:
  for x in special_character:
    print(i + i.title() + x)
    w = i + i.title() + x
    if len(w) >= 6:
      f.write(w+"\n")

#list + special character + list
for i in list_name:
  for x in special_character:
    print(i + x + i)
    w = i + x + i
    if len(w) >= 6:
      f.write(w+"\n")

#list + special character + list capital
for i in list_name:
  for x in special_character:
    print(i + x + i.upper())
    w = i + x + i.upper()
    if len(w) >= 6:
      f.write(w+"\n")

#list + special character + list first capital
for i in list_name:
  for x in special_character:
    print(i + x + i.title())
    w = i + x + i.title()
    if len(w) >= 6:
      f.write(w+"\n")

#list + special character + special character
for i in list_name:
  for x in special_character:
    print(i + x + x)
    w = i + x + x
    if len(w) >= 6:
      f.write(w+"\n")

#list capital + list + list
for i in list_name:
  print(i.upper() + i + i)
  w = i.upper() + i + i
  if len(w) >= 6:
    f.write(w+"\n")

#list capital + list + list capital
for i in list_name:
  print(i.upper() + i + i.upper())
  w = i.upper() + i + i.upper()
  if len(w) >= 6:
    f.write(w+"\n")

#list capital + list + list first capital
for i in list_name:
  print(i.upper() + i + i.title())
  w = i.upper() + i + i.title()
  if len(w) >= 6:
    f.write(w+"\n")

#list capital + list + special character
for i in list_name:
  for x in special_character:
    print(i.upper() + i + x)
    w = i.upper() + i + x
    if len(w) >= 6:
      f.write(w+"\n")

#list capital + list capital + list
for i in list_name:
  print(i.upper() + i.upper() + i)
  w = i.upper() + i.upper() + i
  if len(w) >= 6:
    f.write(w+"\n")

#list capital + list capital + list capital
for i in list_name:
  print(i.upper() + i.upper() + i.upper())
  w = i.upper() + i.upper() + i.upper()
  if len(w) >= 6:
    f.write(w+"\n")

#list capital + list capital + list first capital
for i in list_name:
  print(i.upper() + i.upper() + i.title())
  w = i.upper() + i.upper() + i.title()
  if len(w) >= 6:
    f.write(w+"\n")

#list capital + list capital + special character
for i in list_name:
  for x in special_character:
    print(i.upper() + i.upper() + x)
    w = i.upper() + i.upper() + x
    if len(w) >= 6:
      f.write(w+"\n")

#list capital + list first capital + list
for i in list_name:
  print(i.upper() + i.title() + i)
  w = i.upper() + i.title() + i
  if len(w) >= 6:
    f.write(w+"\n")

#list capital + list first capital + list capital
for i in list_name:
  print(i.upper() + i.title() + i.upper())
  w = i.upper() + i.title() + i.upper()
  if len(w) >= 6:
    f.write(w+"\n")

#list capital + list first capital + list first capital
for i in list_name:
  print(i.upper() + i.title() + i.title())
  w = i.upper() + i.title() + i.title()
  if len(w) >= 6:
    f.write(w+"\n")

#list capital + list first capital + special character
for i in list_name:
  for x in special_character:
    print(i.upper() + i.title() + x)
    w = i.upper() + i.title() + x
    if len(w) >= 6:
      f.write(w+"\n")

#list capital + special character + list
for i in list_name:
  for x in special_character:
    print(i.upper() + x + i)
    w = i.upper() + x + i
    if len(w) >= 6:
      f.write(w+"\n")

#list capital + special character + list capital
for i in list_name:
  for x in special_character:
    print(i.upper() + x + i.upper())
    w = i.upper() + x + i.upper()
    if len(w) >= 6:
      f.write(w+"\n")

#list capital + special character + list first capital
for i in list_name:
  for x in special_character:
    print(i.upper() + x + i.title())
    w = i.upper() + x + i.title()
    if len(w) >= 6:
      f.write(w+"\n")

#list capital + special character +  special character
for i in list_name:
  for x in special_character:
    print(i.upper() + x + x)
    w = i.upper() + x + x
    if len(w) >= 6:
      f.write(w+"\n")

#list first capital + list + list
for i in list_name:
  print(i.title() + i + i)
  w = i.title() + i + i
  if len(w) >= 6:
    f.write(w+"\n")

#list first capital + list + list capital
for i in list_name:
  print(i.title() + i + i.upper())
  w = i.title() + i + i.upper()
  if len(w) >= 6:
    f.write(w+"\n")

#list first capital + list + list first capital
for i in list_name:
  print(i.title() + i + i.title())
  w = i.title() + i + i.title()
  if len(w) >= 6:
    f.write(w+"\n")

#list first capital + list + special character
for i in list_name:
  for x in special_character:
    print(i.title() + i + x)
    w = i.title() + i + x
    if len(w) >= 6:
      f.write(w+"\n")

#list first capital + list capital + list
for i in list_name:
  print(i.title() + i.upper() + i)
  w = i.title() + i.upper() + i
  if len(w) >= 6:
    f.write(w+"\n")

#list first capital + list capital + list capital
for i in list_name:
  print(i.title() + i.upper() + i.upper())
  w = i.title() + i.upper() + i.upper()
  if len(w) >= 6:
    f.write(w+"\n")

#list first capital + list capital + list first capital
for i in list_name:
  print(i.title() + i.upper() + i.title())
  w = i.title() + i.upper() + i.title()
  if len(w) >= 6:
    f.write(w+"\n")

#list first capital + list capital + special character
for i in list_name:
  for x in special_character:
    print(i.title() + i.upper() + x)
    w = i.title() + i.upper() + x
    if len(w) >= 6:
      f.write(w+"\n")

#list first capital + list first capital + list
for i in list_name:
  print(i.title() + i.title() + i)
  w = i.title() + i.title() + i
  if len(w) >= 6:
    f.write(w+"\n")

#list first capital + list first capital + list capital
for i in list_name:
  print(i.title() + i.title() + i.upper())
  w = i.title() + i.title() + i.upper()
  if len(w) >= 6:
    f.write(w+"\n")

#list first capital + list first capital + list first capital
for i in list_name:
  print(i.title() + i.title() + i.upper())
  w = i.title() + i.title() + i.upper()
  if len(w) >= 6:
    f.write(w+"\n")

#list first capital + list first capital + special character
for i in list_name:
  for x in special_character:
    print(i.title() + i.title() + x)
    w = i.title() + i.title() + x
    if len(w) >= 6:
      f.write(w+"\n")

#list first capital + special character + list
for i in list_name:
  for x in special_character:
    print(i.title() + x + i)
    w = i.title() + x + i
    if len(w) >= 6:
      f.write(w+"\n")

#list first capital + special character + list capital
for i in list_name:
  for x in special_character:
    print(i.title() + x + i.upper())
    w = i.title() + x + i.upper()
    if len(w) >= 6:
      f.write(w+"\n")

#list first capital + special character + list first capital
for i in list_name:
  for x in special_character:
    print(i.title() + x + i.title())
    w = i.title() + x + i.title()
    if len(w) >= 6:
      f.write(w+"\n")

#list first capital + special character + special character
for i in list_name:
  for x in special_character:
    print(i.title() + x + x)
    w = i.title() + x + x
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list + list
for i in list_name:
  for x in special_character:
    print(x + i + i)
    w = x + i + i
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list + list capital
for i in list_name:
  for x in special_character:
    print(x + i + i.upper())
    w = x + i + i.upper()
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list + list first capital
for i in list_name:
  for x in special_character:
    print(x + i + i.title())
    w = x + i + i.title()
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list + special character
for i in list_name:
  for x in special_character:
    print(x + i + x)
    w = x + i + x
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list capital + list
for i in list_name:
  for x in special_character:
    print(x + i.upper() + i)
    w = x + i.upper() + i
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list capital + list capital
for i in list_name:
  for x in special_character:
    print(x + i.upper() + i.upper())
    w = x + i.upper() + i.upper()
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list capital + list first capital
for i in list_name:
  for x in special_character:
    print(x + i.upper() + i.title())
    w = x + i.upper() + i.title()
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list capital + special character
for i in list_name:
  for x in special_character:
    print(x + i.upper() + x)
    w = x + i.upper() + x
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list first capital + list
for i in list_name:
  for x in special_character:
    print(x + i.title() + i)
    w = x + i + i
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list first capital + list capital
for i in list_name:
  for x in special_character:
    print(x + i.title() + i.upper())
    w = x + i.title() + i.upper()
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list first capital + list first capital
for i in list_name:
  for x in special_character:
    print(x + i.title() + i.title())
    w = x + i.title() + i.title()
    if len(w) >= 6:
      f.write(w+"\n")

#special character + list first capital + special character
for i in list_name:
  for x in special_character:
    print(x + i.title() + x)
    w = x + i.title() + x
    if len(w) >= 6:
      f.write(w+"\n")

#special character + special character + list
for i in list_name:
  for x in special_character:
    print(x + x + i)
    w = x + x + i
    if len(w) >= 6:
      f.write(w+"\n")

#special character + special character + list capital
for i in list_name:
  for x in special_character:
    print(x + x + i.upper())
    w = x + x + i.upper()
    if len(w) >= 6:
      f.write(w+"\n")

#special character + special character + list first capital
for i in list_name:
  for x in special_character:
    print(x + x + i.title())
    w = x + x + i.title()
    if len(w) >= 6:
      f.write(w+"\n")

#special character + special character + special character
for i in list_name:
  for x in special_character:
    print(x + x + x)
    w = x + x + x
    if len(w) >= 6:
      f.write(w+"\n")

# %%
import random
with open(first_name + "_pwd.txt",'r') as source:
    data = [ (random.random(), line) for line in source ]
data.sort()
with open(first_name + "_pwd_shuffle.txt",'w') as target:
    for _, line in data:
        target.write( line )
